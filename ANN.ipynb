# %% [markdown]
# <a href="https://colab.research.google.com/github/Parikshith21/ML_LAB/blob/master/ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
                            #w5 = w5 + N*derivate of etotal/w5 --> example of updation of weight      (0.002)

def reweight_level2():
    derivative_of_error = output[0] - estimated_output[0]                
    w2[0][0] = w2[0][0] + 0.002 * (derivative_of_error*hidden_out[0])   #update weights
    w2[1][0] = w2[1][0] + 0.002 * (derivative_of_error*hidden_out[1])
    
def reweight_level1():
    w1[0][0] = w1[0][0] + 0.002 * (x[0] * hidden_out[0]*w2[0][0])
    w1[0][1] = w1[0][1] + 0.002 * (x[0] * hidden_out[1]*w2[1][0])
        
    w1[1][0] = w1[1][0] + 0.002 * (x[1] * hidden_out[0]*w2[0][0])
    w1[1][1] = w1[1][1] + 0.002 * (x[1] * hidden_out[1]*w2[1][0])

# %% [markdown]
# **x[2,5]----(w1)----H----(w2)----y[1]**

# %%
def reupdate(a):
    i = 0
    b = [None] * len(a)
    for x in a:
        a[i] = np.maximum(0,x)
        i = i + 1
    print(w1)
    return a

# %%
w1 = [[0.7,0.5],
      [0.9,0.7]]

w2 = [[0.5],
      [0.6]]

x = [2,5]
output = [1]

# %%
for i in range(100):
    hidden_in = np.matmul(w1,x)
    hidden_out = reupdate(hidden_in)
    print("hidden_out:")
    print(hidden_out)
    estimated_output = np.matmul(hidden_out,w2)
    print("Estimated output")
    print(estimated_output)
    print("error :", estimated_output-output)
    reweight_level2()
    reweight_level1()
    print(w1)
# Out:
# [[0.7, 0.5], [0.9, 0.7]]
# hidden_out:
# [3.9 5.3]
# Estimated output
# [5.13]
# error : [4.13]
# [[0.7072974616, 0.5117919064], [0.9182436540000001, 0.729479766]]
# [[0.7072974616, 0.5117919064], [0.9182436540000001, 0.729479766]]
# hidden_out:
# [3.97355446 5.48388614]
# Estimated output
# [4.90903126]
# error : [3.90903126]
# [[0.7142387923990112, 0.5230524882608232], [0.9355969809975283, 0.7576312206520578]]
# [[0.7142387923990112, 0.5230524882608232], [0.9355969809975283, 0.7576312206520578]]
# hidden_out:
# [4.04374003 5.65935007]
# Estimated output
# [4.67120381]
# error : [3.67120381]
# [[0.7208224818046495, 0.5337327091254029], [0.9520562045116241, 0.7843317728135073]]
# [[0.7208224818046495, 0.5337327091254029], [0.9520562045116241, 0.7843317728135073]]
# hidden_out:
# [4.11030851 5.82577127]
# Estimated output
# [4.42158968]
# error : [3.42158968]
# [[0.7270521005152564, 0.5437979776394867], [0.9676302512881412, 0.8094949440987166]]
# ...
