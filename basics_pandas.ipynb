# %% [markdown]
# <a href="https://colab.research.google.com/github/Parikshith21/ML_LAB/blob/master/basics_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=[1,2,3,4,21,6,5]

# %%
series=pd.Series(data)

# %%
series
# Out:
# 0     1
# 1     2
# 2     3
# 3     4
# 4    21
# 5     6
# 6     5
# dtype: int64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
series=pd.Series(data,index=['a','b','c','d','f','g','h'])

# %%
series
# Out:
# a     1
# b     2
# c     3
# d     4
# f    21
# g     6
# h     5
# dtype: int64

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#     0
# 0   1
# 1   2
# 2   3
# 3   4
# 4  21
# 5   6
# 6   5

# %%
dict={'b':['a1','a2','a3'],'count':[20,21,22]}

# %%
dict.keys()
# Out:
# dict_keys(['b', 'count'])

# %%
dict.values()
# Out:
# dict_values([['a1', 'a2', 'a3'], [20, 21, 22]])

# %%
df=pd.DataFrame(dict)

# %%
df
# Out:
#     b  count
# 0  a1     20
# 1  a2     21
# 2  a3     22

# %%
s1=pd.Series([6,12],index=['a','b'])

# %%
s1
# Out:
# a     6
# b    12
# dtype: int64

# %%
df=pd.DataFrame(s1)

# %%
df
# Out:
#     0
# a   6
# b  12

# %%
p1=['a1','a2','a3','a4']
q1=[12,13,14,15]
r1=['g1','g2','g3','g4']

# %%
df1=pd.DataFrame({'players':p1,'score':q1,'title':r1})

# %%
df1
# Out:
#   players  score title
# 0      a1     12    g1
# 1      a2     13    g2
# 2      a3     14    g3
# 3      a4     15    g4

# %%
import pandas as pd
finds=pd.read_csv("C:\\Users\\Student\\Desktop\\data_set\\finds_1.csv")

# %%
finds
# Out:
#       Sky Airtemp Humidity    Wind Water Forecast WaterSport
# 0   Sunny    Warm   Normal  Strong  Warm     Same        Yes
# 1   Sunny    Warm     High  Strong  Warm     Same        Yes
# 2  Cloudy    Cold     High  Strong  Warm   Change         No
# 3   Sunny    Warm     High  Strong  Cool   Change        Yes

# %%
type(finds)
# Out:
# pandas.core.frame.DataFrame

# %%
finds.head()
# Out:
#       Sky Airtemp Humidity    Wind Water Forecast WaterSport
# 0   Sunny    Warm   Normal  Strong  Warm     Same        Yes
# 1   Sunny    Warm     High  Strong  Warm     Same        Yes
# 2  Cloudy    Cold     High  Strong  Warm   Change         No
# 3   Sunny    Warm     High  Strong  Cool   Change        Yes

# %%
finds.tail(2)
# Out:
#       Sky Airtemp Humidity    Wind Water Forecast WaterSport
# 2  Cloudy    Cold     High  Strong  Warm   Change         No
# 3   Sunny    Warm     High  Strong  Cool   Change        Yes

# %%
finds.shape
# Out:
# (4, 7)

# %%
finds.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 7 columns):
# Sky           4 non-null object
# Airtemp       4 non-null object
# Humidity      4 non-null object
# Wind          4 non-null object
# Water         4 non-null object
# Forecast      4 non-null object
# WaterSport    4 non-null object
# dtypes: object(7)
# memory usage: 152.0+ bytes

# %%
import pandas as pd
hd=pd.read_csv("C://Users//Student//Desktop//data_set/heartdisease.csv")

# %%
hd
# Out:
#      63.0  1.0  1.0.1  145.0  233.0  1.0.2  2.0  150.0  0.0  2.3  3.0 0.0.1  \
# 0    67.0  1.0    4.0  160.0  286.0    0.0  2.0  108.0  1.0  1.5  2.0   3.0
# 1    67.0  1.0    4.0  120.0  229.0    0.0  2.0  129.0  1.0  2.6  2.0   2.0
# 2    37.0  1.0    3.0  130.0  250.0    0.0  0.0  187.0  0.0  3.5  3.0   0.0
# 3    41.0  0.0    2.0  130.0  204.0    0.0  2.0  172.0  0.0  1.4  1.0   0.0
# 4    56.0  1.0    2.0  120.0  236.0    0.0  0.0  178.0  0.0  0.8  1.0   0.0
# 5    62.0  0.0    4.0  140.0  268.0    0.0  2.0  160.0  0.0  3.6  3.0   2.0
# 6    57.0  0.0    4.0  120.0  354.0    0.0  0.0  163.0  1.0  0.6  1.0   0.0
# 7    63.0  1.0    4.0  130.0  254.0    0.0  2.0  147.0  0.0  1.4  2.0   1.0
# 8    53.0  1.0    4.0  140.0  203.0    1.0  2.0  155.0  1.0  3.1  3.0   0.0
# 9    57.0  1.0    4.0  140.0  192.0    0.0  0.0  148.0  0.0  0.4  2.0   0.0
# 10   56.0  0.0    2.0  140.0  294.0    0.0  2.0  153.0  0.0  1.3  2.0   0.0
# ...

# %%
hd.head()
# Out:
#    63.0  1.0  1.0.1  145.0  233.0  1.0.2  2.0  150.0  0.0  2.3  3.0 0.0.1  \
# 0  67.0  1.0    4.0  160.0  286.0    0.0  2.0  108.0  1.0  1.5  2.0   3.0
# 1  67.0  1.0    4.0  120.0  229.0    0.0  2.0  129.0  1.0  2.6  2.0   2.0
# 2  37.0  1.0    3.0  130.0  250.0    0.0  0.0  187.0  0.0  3.5  3.0   0.0
# 3  41.0  0.0    2.0  130.0  204.0    0.0  2.0  172.0  0.0  1.4  1.0   0.0
# 4  56.0  1.0    2.0  120.0  236.0    0.0  0.0  178.0  0.0  0.8  1.0   0.0
#
#    6.0  0
# 0  3.0  2
# 1  7.0  1
# 2  3.0  0
# 3  3.0  0
# 4  3.0  0

# %%
hd.tail()
# Out:
#      63.0  1.0  1.0.1  145.0  233.0  1.0.2  2.0  150.0  0.0  2.3  3.0 0.0.1  \
# 297  45.0  1.0    1.0  110.0  264.0    0.0  0.0  132.0  0.0  1.2  2.0   0.0
# 298  68.0  1.0    4.0  144.0  193.0    1.0  0.0  141.0  0.0  3.4  2.0   2.0
# 299  57.0  1.0    4.0  130.0  131.0    0.0  0.0  115.0  1.0  1.2  2.0   1.0
# 300  57.0  0.0    2.0  130.0  236.0    0.0  2.0  174.0  0.0  0.0  2.0   1.0
# 301  38.0  1.0    3.0  138.0  175.0    0.0  0.0  173.0  0.0  0.0  1.0     ?
#
#      6.0  0
# 297  7.0  1
# 298  7.0  2
# 299  7.0  3
# 300  3.0  1
# 301  3.0  0

# %%
hd.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302 entries, 0 to 301
# Data columns (total 14 columns):
# 63.0     302 non-null float64
# 1.0      302 non-null float64
# 1.0.1    302 non-null float64
# 145.0    302 non-null float64
# 233.0    302 non-null float64
# 1.0.2    302 non-null float64
# 2.0      302 non-null float64
# 150.0    302 non-null float64
# 0.0      302 non-null float64
# 2.3      302 non-null float64
# 3.0      302 non-null float64
# 0.0.1    302 non-null object
# 6.0      302 non-null object
# 0        302 non-null int64
# dtypes: float64(11), int64(1), object(2)
# memory usage: 30.7+ KB

# %%
hd.mean()
# Out:
# 63.0      54.410596
# 1.0        0.678808
# 1.0.1      3.165563
# 145.0    131.645695
# 233.0    246.738411
# 1.0.2      0.145695
# 2.0        0.986755
# 150.0    149.605960
# 0.0        0.327815
# 2.3        1.035430
# 3.0        1.596026
# 0          0.940397
# dtype: float64

# %%
finds.mean
# Out:
# <bound method DataFrame.mean of       Sky Airtemp Humidity    Wind Water Forecast WaterSport
# 0   Sunny    Warm   Normal  Strong  Warm     Same        Yes
# 1   Sunny    Warm     High  Strong  Warm     Same        Yes
# 2  Cloudy    Cold     High  Strong  Warm   Change         No
# 3   Sunny    Warm     High  Strong  Cool   Change        Yes>

# %%
hd.max()
# Out:
# 63.0      77
# 1.0        1
# 1.0.1      4
# 145.0    200
# 233.0    564
# 1.0.2      1
# 2.0        2
# 150.0    202
# 0.0        1
# 2.3      6.2
# 3.0        3
# 0.0.1      ?
# 6.0        ?
# 0          4
# dtype: object

# %%
hd.describe()
# Out:
#              63.0         1.0       1.0.1       145.0       233.0       1.0.2  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.410596    0.678808    3.165563  131.645695  246.738411    0.145695
# std      9.040163    0.467709    0.953612   17.612202   51.856829    0.353386
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     55.500000    1.000000    3.000000  130.000000  241.500000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#               2.0       150.0         0.0         2.3         3.0           0
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.986755  149.605960    0.327815    1.035430    1.596026    0.940397
# ...

# %%
finds=finds.rename(columns={'unnamed:1':'ac'})

# %%
finds
# Out:
#       Sky Airtemp Humidity    Wind Water Forecast WaterSport
# 0   Sunny    Warm   Normal  Strong  Warm     Same        Yes
# 1   Sunny    Warm     High  Strong  Warm     Same        Yes
# 2  Cloudy    Cold     High  Strong  Warm   Change         No
# 3   Sunny    Warm     High  Strong  Cool   Change        Yes

# %%
hd.iloc[:0,:10]
# Out:
# Empty DataFrame
# Columns: [63.0, 1.0, 1.0.1, 145.0, 233.0, 1.0.2, 2.0, 150.0, 0.0, 2.3]
# Index: []

# %%
hd.iloc[-1:,-2:]
# Out:
#      6.0  0
# 301  3.0  0

# %%
hd.drop(columns=['63.0'])
# Out:
#      1.0  1.0.1  145.0  233.0  1.0.2  2.0  150.0  0.0  2.3  3.0 0.0.1  6.0  0
# 0    1.0    4.0  160.0  286.0    0.0  2.0  108.0  1.0  1.5  2.0   3.0  3.0  2
# 1    1.0    4.0  120.0  229.0    0.0  2.0  129.0  1.0  2.6  2.0   2.0  7.0  1
# 2    1.0    3.0  130.0  250.0    0.0  0.0  187.0  0.0  3.5  3.0   0.0  3.0  0
# 3    0.0    2.0  130.0  204.0    0.0  2.0  172.0  0.0  1.4  1.0   0.0  3.0  0
# 4    1.0    2.0  120.0  236.0    0.0  0.0  178.0  0.0  0.8  1.0   0.0  3.0  0
# 5    0.0    4.0  140.0  268.0    0.0  2.0  160.0  0.0  3.6  3.0   2.0  3.0  3
# 6    0.0    4.0  120.0  354.0    0.0  0.0  163.0  1.0  0.6  1.0   0.0  3.0  0
# 7    1.0    4.0  130.0  254.0    0.0  2.0  147.0  0.0  1.4  2.0   1.0  7.0  2
# 8    1.0    4.0  140.0  203.0    1.0  2.0  155.0  1.0  3.1  3.0   0.0  7.0  1
# 9    1.0    4.0  140.0  192.0    0.0  0.0  148.0  0.0  0.4  2.0   0.0  6.0  0
# 10   0.0    2.0  140.0  294.0    0.0  2.0  153.0  0.0  1.3  2.0   0.0  3.0  0
# ...

# %%
hd.drop(2)
# Out:
#      63.0  1.0  1.0.1  145.0  233.0  1.0.2  2.0  150.0  0.0  2.3  3.0 0.0.1  \
# 0    67.0  1.0    4.0  160.0  286.0    0.0  2.0  108.0  1.0  1.5  2.0   3.0
# 1    67.0  1.0    4.0  120.0  229.0    0.0  2.0  129.0  1.0  2.6  2.0   2.0
# 3    41.0  0.0    2.0  130.0  204.0    0.0  2.0  172.0  0.0  1.4  1.0   0.0
# 4    56.0  1.0    2.0  120.0  236.0    0.0  0.0  178.0  0.0  0.8  1.0   0.0
# 5    62.0  0.0    4.0  140.0  268.0    0.0  2.0  160.0  0.0  3.6  3.0   2.0
# 6    57.0  0.0    4.0  120.0  354.0    0.0  0.0  163.0  1.0  0.6  1.0   0.0
# 7    63.0  1.0    4.0  130.0  254.0    0.0  2.0  147.0  0.0  1.4  2.0   1.0
# 8    53.0  1.0    4.0  140.0  203.0    1.0  2.0  155.0  1.0  3.1  3.0   0.0
# 9    57.0  1.0    4.0  140.0  192.0    0.0  0.0  148.0  0.0  0.4  2.0   0.0
# 10   56.0  0.0    2.0  140.0  294.0    0.0  2.0  153.0  0.0  1.3  2.0   0.0
# 11   56.0  1.0    3.0  130.0  256.0    1.0  2.0  142.0  1.0  0.6  2.0   1.0
# ...
